# %% [markdown]
# <a href="https://colab.research.google.com/github/mmmullooly123/DeepLearning_CSCI167/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-9xzzoxsj
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-9xzzoxsj
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=910c925f4f61ccc21d3663757f51398eb64758e63e0aec018349f1ee29a44aa0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zty7n5tn/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    # Layer 1: Conv1d(1 input channel → 15 output channels, kernel=3, stride=2, padding=0/"valid")
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # Layer 2: Conv1d(15 → 15, kernel=3, stride=2, padding=0)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # Layer 3: Conv1d(15 → 15, kernel=3, stride=2, padding=0)
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),

    # Flatten (to turn [batch, 15, 4] into [batch, 60])
    nn.Flatten(),

    # Fully connected (Linear) layer to 10 output classes
    nn.Linear(in_features=60, out_features=10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.849707, train error 72.40,  val loss 1.869075, percent error 74.10
# Epoch     1, train loss 1.477351, train error 59.03,  val loss 1.483092, percent error 60.70
# Epoch     2, train loss 1.420369, train error 58.70,  val loss 1.412611, percent error 58.80
# Epoch     3, train loss 1.280930, train error 51.42,  val loss 1.272047, percent error 55.30
# Epoch     4, train loss 1.225769, train error 49.80,  val loss 1.246050, percent error 53.20
# Epoch     5, train loss 1.229136, train error 51.92,  val loss 1.254593, percent error 52.80
# Epoch     6, train loss 1.118105, train error 48.20,  val loss 1.126843, percent error 49.00
# Epoch     7, train loss 0.953712, train error 37.97,  val loss 0.971831, percent error 39.80
# Epoch     8, train loss 0.828289, train error 32.12,  val loss 0.880368, percent error 35.70
# Epoch     9, train loss 0.761159, train error 29.40,  val loss 0.822557, percent error 34.20
# Epoch    10, train loss 0.661449, train error 25.75,  val loss 0.724619, percent error 29.40
# Epoch    11, train loss 0.609765, train error 23.30,  val loss 0.684053, percent error 26.60
# Epoch    12, train loss 0.536366, train error 20.07,  val loss 0.626035, percent error 23.00
# Epoch    13, train loss 0.541743, train error 20.57,  val loss 0.630018, percent error 23.20
# Epoch    14, train loss 0.480923, train error 18.15,  val loss 0.605623, percent error 21.70
# Epoch    15, train loss 0.406441, train error 15.97,  val loss 0.546084, percent error 20.00
# Epoch    16, train loss 0.365642, train error 13.30,  val loss 0.531217, percent error 19.10
# Epoch    17, train loss 0.316962, train error 11.43,  val loss 0.452582, percent error 15.20
# Epoch    18, train loss 0.323161, train error 12.25,  val loss 0.480762, percent error 18.00
# Epoch    19, train loss 0.343989, train error 12.95,  val loss 0.514213, percent error 17.50
# Epoch    20, train loss 0.254814, train error 9.72,  val loss 0.433651, percent error 15.30
# Epoch    21, train loss 0.218220, train error 8.03,  val loss 0.403643, percent error 14.70
# Epoch    22, train loss 0.207750, train error 7.35,  val loss 0.415620, percent error 13.80
# Epoch    23, train loss 0.199541, train error 7.22,  val loss 0.405360, percent error 13.90
# Epoch    24, train loss 0.180723, train error 6.32,  val loss 0.405006, percent error 13.00
# Epoch    25, train loss 0.211375, train error 7.53,  val loss 0.431686, percent error 14.40
# Epoch    26, train loss 0.159136, train error 5.32,  val loss 0.392401, percent error 12.70
# Epoch    27, train loss 0.189135, train error 6.68,  val loss 0.429640, percent error 13.30
# Epoch    28, train loss 0.185308, train error 6.72,  val loss 0.448529, percent error 13.30
# Epoch    29, train loss 0.168064, train error 5.68,  val loss 0.407234, percent error 12.80
# Epoch    30, train loss 0.171182, train error 6.20,  val loss 0.421553, percent error 14.20
# Epoch    31, train loss 0.179307, train error 6.32,  val loss 0.387006, percent error 11.80
# Epoch    32, train loss 0.138282, train error 4.32,  val loss 0.394166, percent error 11.90
# Epoch    33, train loss 0.130828, train error 4.00,  val loss 0.391528, percent error 12.00
# Epoch    34, train loss 0.153566, train error 5.60,  val loss 0.415760, percent error 12.50
# Epoch    35, train loss 0.133682, train error 4.43,  val loss 0.398710, percent error 12.60
# Epoch    36, train loss 0.115622, train error 3.88,  val loss 0.405339, percent error 11.10
# Epoch    37, train loss 0.150908, train error 5.43,  val loss 0.444515, percent error 12.10
# Epoch    38, train loss 0.131643, train error 4.38,  val loss 0.427182, percent error 11.20
# Epoch    39, train loss 0.112317, train error 3.95,  val loss 0.417798, percent error 11.70
# Epoch    40, train loss 0.101013, train error 2.90,  val loss 0.399421, percent error 11.90
# Epoch    41, train loss 0.091739, train error 2.85,  val loss 0.394493, percent error 12.40
# Epoch    42, train loss 0.088919, train error 2.45,  val loss 0.382019, percent error 11.30
# Epoch    43, train loss 0.088295, train error 2.57,  val loss 0.391711, percent error 12.20
# Epoch    44, train loss 0.088706, train error 2.68,  val loss 0.399217, percent error 11.20
# Epoch    45, train loss 0.085579, train error 2.38,  val loss 0.403544, percent error 11.10
# Epoch    46, train loss 0.083065, train error 2.32,  val loss 0.396938, percent error 11.30
# Epoch    47, train loss 0.082171, train error 2.45,  val loss 0.408364, percent error 11.80
# Epoch    48, train loss 0.080137, train error 2.53,  val loss 0.406241, percent error 10.80
# Epoch    49, train loss 0.076100, train error 1.90,  val loss 0.404642, percent error 11.40
# Epoch    50, train loss 0.085886, train error 2.70,  val loss 0.432872, percent error 12.10
# Epoch    51, train loss 0.073070, train error 2.00,  val loss 0.411235, percent error 11.20
# Epoch    52, train loss 0.072011, train error 1.95,  val loss 0.415296, percent error 11.80
# Epoch    53, train loss 0.078966, train error 2.18,  val loss 0.416860, percent error 11.80
# Epoch    54, train loss 0.071306, train error 1.97,  val loss 0.420668, percent error 11.50
# Epoch    55, train loss 0.080354, train error 2.20,  val loss 0.422575, percent error 11.70
# Epoch    56, train loss 0.070846, train error 1.70,  val loss 0.433342, percent error 11.40
# Epoch    57, train loss 0.074710, train error 2.28,  val loss 0.442283, percent error 11.50
# Epoch    58, train loss 0.068640, train error 1.72,  val loss 0.421859, percent error 11.90
# Epoch    59, train loss 0.064135, train error 1.68,  val loss 0.411145, percent error 11.40
# Epoch    60, train loss 0.059559, train error 1.38,  val loss 0.422788, percent error 11.40
# Epoch    61, train loss 0.062836, train error 1.65,  val loss 0.425824, percent error 11.30
# Epoch    62, train loss 0.058804, train error 1.40,  val loss 0.424869, percent error 11.50
# Epoch    63, train loss 0.058732, train error 1.35,  val loss 0.422506, percent error 11.60
# Epoch    64, train loss 0.057947, train error 1.35,  val loss 0.420903, percent error 11.50
# Epoch    65, train loss 0.058358, train error 1.53,  val loss 0.424593, percent error 11.50
# Epoch    66, train loss 0.055763, train error 1.22,  val loss 0.425353, percent error 11.40
# Epoch    67, train loss 0.055259, train error 1.32,  val loss 0.429259, percent error 11.40
# Epoch    68, train loss 0.056770, train error 1.22,  val loss 0.435700, percent error 12.00
# Epoch    69, train loss 0.056996, train error 1.35,  val loss 0.436155, percent error 11.60
# Epoch    70, train loss 0.053466, train error 1.15,  val loss 0.439081, percent error 11.70
# Epoch    71, train loss 0.052298, train error 1.07,  val loss 0.439679, percent error 11.20
# Epoch    72, train loss 0.052212, train error 1.00,  val loss 0.438940, percent error 11.60
# Epoch    73, train loss 0.052047, train error 1.20,  val loss 0.437312, percent error 11.20
# Epoch    74, train loss 0.050854, train error 0.97,  val loss 0.438719, percent error 11.20
# Epoch    75, train loss 0.051686, train error 1.05,  val loss 0.443671, percent error 11.60
# Epoch    76, train loss 0.049691, train error 1.07,  val loss 0.440577, percent error 11.40
# Epoch    77, train loss 0.051824, train error 1.03,  val loss 0.444107, percent error 12.00
# Epoch    78, train loss 0.053334, train error 1.32,  val loss 0.454288, percent error 11.30
# Epoch    79, train loss 0.048629, train error 0.95,  val loss 0.446769, percent error 11.60
# Epoch    80, train loss 0.047291, train error 0.85,  val loss 0.444749, percent error 11.50
# Epoch    81, train loss 0.047477, train error 0.85,  val loss 0.446984, percent error 11.70
# Epoch    82, train loss 0.047085, train error 0.80,  val loss 0.451799, percent error 11.70
# Epoch    83, train loss 0.047448, train error 0.88,  val loss 0.447573, percent error 11.60
# Epoch    84, train loss 0.046766, train error 0.85,  val loss 0.450087, percent error 11.50
# Epoch    85, train loss 0.046754, train error 0.72,  val loss 0.454721, percent error 11.80
# Epoch    86, train loss 0.046153, train error 0.75,  val loss 0.452513, percent error 11.80
# Epoch    87, train loss 0.046128, train error 0.80,  val loss 0.455899, percent error 11.50
# Epoch    88, train loss 0.046253, train error 0.88,  val loss 0.452082, percent error 11.70
# Epoch    89, train loss 0.045744, train error 0.75,  val loss 0.454950, percent error 11.50
# Epoch    90, train loss 0.044929, train error 0.80,  val loss 0.452314, percent error 11.40
# Epoch    91, train loss 0.045479, train error 0.85,  val loss 0.457392, percent error 11.50
# Epoch    92, train loss 0.046475, train error 0.90,  val loss 0.463292, percent error 11.80
# Epoch    93, train loss 0.044247, train error 0.68,  val loss 0.458532, percent error 11.60
# Epoch    94, train loss 0.044134, train error 0.72,  val loss 0.456892, percent error 11.30
# Epoch    95, train loss 0.044153, train error 0.65,  val loss 0.459696, percent error 11.40
# Epoch    96, train loss 0.043838, train error 0.75,  val loss 0.456226, percent error 11.40
# Epoch    97, train loss 0.043355, train error 0.70,  val loss 0.461132, percent error 11.50
# Epoch    98, train loss 0.043165, train error 0.68,  val loss 0.462880, percent error 11.60
# Epoch    99, train loss 0.043572, train error 0.72,  val loss 0.464681, percent error 11.60
